# %% [markdown]
# # Model evaluation

# %%
import pickle
file = open('X_test', 'rb')

# dump information to that file
X_test = pickle.load(file)

# close the file
file.close()

# %%
import pickle
file = open('y_test', 'rb')

# dump information to that file
y_test = pickle.load(file)

# close the file
file.close()

# %%
import os
import numpy as np
import pandas as pd
from matplotlib.pyplot import imread
import matplotlib.pyplot as plt
from PIL import Image
import PIL
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm

# %% [markdown]
# ## Color change

# %%
X_test[3].shape
# Out:
# (256, 256)

# %%
X_test=np.stack([X_test]*3, axis=-1)

# %%
plt.imshow(X_test[3])

# %%
plt.imshow(X_test_product)

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

X_test=tf.keras.applications.vgg16.preprocess_input(
    X_test, data_format=None
)

# %% [markdown]
# ## Evaluate Model

# %%
from tensorflow.keras import models
loaded_model = models.load_model('/Users/davidmedioni/code/dino120798/finalproject/models')

# %%
loaded_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 8, 8, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               16384500
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 2004
# =================================================================
# Total params: 31,101,192
# Trainable params: 31,101,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_test[:3].shape
# Out:
# (3, 256, 256, 3)

# %%
y_test[3].shape
# Out:
# (4,)

# %%
loaded_model.predict(X_test[:3], verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[1.3795666e-12, 1.0000000e+00, 1.8727610e-13, 1.6707087e-16],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [2.4316719e-25, 1.0000000e+00, 1.3589413e-29, 3.4511717e-27]],
#       dtype=float32)

# %% [markdown]
# ## Scores

# %%
y_true = y_test

# %%
y_pred = loaded_model.predict(y_true)

# %%
number_list = y_pred

(unique, counts) = np.unique(number_list, return_counts=True)
frequencies = np.asarray((unique, counts)).T

print(frequencies)

# %%
number_list = y_true

(unique, counts) = np.unique(number_list, return_counts=True)
frequencies = np.asarray((unique, counts)).T

print(frequencies)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
cm = confusion_matrix(y_true,y_pred)

# %%
labels = [‘bacterial_pneumonia’, ‘covid-19’, ‘normal’, ‘viral_pneumonia’]

# %%
df_cm = pd.DataFrame(cm, index = [i for i in labels],
                  columns = [i for i in labels])

# %%
sns.heatmap(df_cm, annot=True)

# %%
target_names =['bacterial_pneumonia', 'covid-19', 'normal', 'viral_pneumonia']
print(classification_report(y_true, y_pred, target_names=target_names))
